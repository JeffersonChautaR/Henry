# %% [markdown]
# Instalacion de Librerias

# %%
! pip install pandas numpy seaborn matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Importacion de Librerias

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %% [markdown]
# Inicio de codigo para limpieza de datos

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
games = pd.read_csv(r"C:\Users\USER\Desktop\Proyecto\Files\game.csv")

# %% [markdown]
# Limpieza de datos

# %%
games.head()
# Out:
#    season_id  team_id_home team_abbreviation_home           team_name_home  \
# 0      21946    1610610035                    HUS          Toronto Huskies
# 1      21946    1610610034                    BOM        St. Louis Bombers
# 2      21946    1610610032                    PRO  Providence Steamrollers
# 3      21946    1610610025                    CHS            Chicago Stags
# 4      21946    1610610028                    DEF          Detroit Falcons
#
#     game_id            game_date matchup_home wl_home  min  fgm_home  ...  \
# 0  24600001  1946-11-01 00:00:00  HUS vs. NYK       L    0      25.0  ...
# 1  24600003  1946-11-02 00:00:00  BOM vs. PIT       W    0      20.0  ...
# 2  24600002  1946-11-02 00:00:00  PRO vs. BOS       W    0      21.0  ...
# 3  24600004  1946-11-02 00:00:00  CHS vs. NYK       W    0      21.0  ...
# 4  24600005  1946-11-02 00:00:00  DEF vs. WAS       L    0      10.0  ...
#
# ...

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65698 entries, 0 to 65697
# Data columns (total 55 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   season_id               65698 non-null  int64
#  1   team_id_home            65698 non-null  int64
#  2   team_abbreviation_home  65698 non-null  object
#  3   team_name_home          65698 non-null  object
#  4   game_id                 65698 non-null  int64
#  5   game_date               65698 non-null  object
#  6   matchup_home            65698 non-null  object
#  7   wl_home                 65696 non-null  object
#  8   min                     65698 non-null  int64
#  9   fgm_home                65685 non-null  float64
#  10  fga_home                50251 non-null  float64
#  11  fg_pct_home             50208 non-null  float64
#  12  fg3m_home               52480 non-null  float64
#  13  fg3a_home               47015 non-null  float64
# ...

# %%
games = games[['game_date', 'game_id', 'team_id_home', 'team_id_away', 'pts_home', 'pts_away']]
games.head()
# Out:
#              game_date   game_id  team_id_home  team_id_away  pts_home  \
# 0  1946-11-01 00:00:00  24600001    1610610035    1610612752      66.0
# 1  1946-11-02 00:00:00  24600003    1610610034    1610610031      56.0
# 2  1946-11-02 00:00:00  24600002    1610610032    1610612738      59.0
# 3  1946-11-02 00:00:00  24600004    1610610025    1610612752      63.0
# 4  1946-11-02 00:00:00  24600005    1610610028    1610610036      33.0
#
#    pts_away
# 0      68.0
# 1      51.0
# 2      53.0
# 3      47.0
# 4      50.0

# %%
games['game_date'] = pd.to_datetime(games['game_date'])

# %%
games.head()
# Out:
#    game_date   game_id  team_id_home  team_id_away  pts_home  pts_away
# 0 1946-11-01  24600001    1610610035    1610612752      66.0      68.0
# 1 1946-11-02  24600003    1610610034    1610610031      56.0      51.0
# 2 1946-11-02  24600002    1610610032    1610612738      59.0      53.0
# 3 1946-11-02  24600004    1610610025    1610612752      63.0      47.0
# 4 1946-11-02  24600005    1610610028    1610610036      33.0      50.0

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65698 entries, 0 to 65697
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   game_date     65698 non-null  datetime64[ns]
#  1   game_id       65698 non-null  int64
#  2   team_id_home  65698 non-null  int64
#  3   team_id_away  65698 non-null  int64
#  4   pts_home      65698 non-null  float64
#  5   pts_away      65698 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(3)
# memory usage: 3.0 MB

# %%
games['game_date'] = pd.to_datetime(games['game_date'])

# Filtrar por rango de años (2013 a 2023, inclusive)
games_fecha_filtrado = games[(games['game_date'].dt.year >= 2013) & (games['game_date'].dt.year <= 2023)]

games_fecha_filtrado
# Out:
#        game_date   game_id  team_id_home  team_id_away  pts_home  pts_away
# 52071 2013-04-20  41200161    1610612743    1610612744      97.0      95.0
# 52072 2013-04-20  41200131    1610612751    1610612741     106.0      89.0
# 52073 2013-04-20  41200111    1610612752    1610612738      85.0      78.0
# 52074 2013-04-20  41200171    1610612746    1610612763     112.0      91.0
# 52075 2013-04-21  41200121    1610612754    1610612737     107.0      90.0
# ...          ...       ...           ...           ...       ...       ...
# 65693 2023-06-07  42200403    1610612748    1610612743      94.0     109.0
# 65694 2023-06-09  42200404    1610612748    1610612743      95.0     108.0
# 65695 2023-06-12  42200405    1610612743    1610612748      94.0      89.0
# 65696 2023-02-19  32200001    1610616834    1610616833     175.0     184.0
# 65697 2023-02-19  32200001    1610616834    1610616833     175.0     184.0
#
# [13627 rows x 6 columns]

# %%
games_fecha_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13627 entries, 52071 to 65697
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   game_date     13627 non-null  datetime64[ns]
#  1   game_id       13627 non-null  int64
#  2   team_id_home  13627 non-null  int64
#  3   team_id_away  13627 non-null  int64
#  4   pts_home      13627 non-null  float64
#  5   pts_away      13627 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(3)
# memory usage: 745.2 KB

# %%
games_fecha_filtrado['year'] = games_fecha_filtrado['game_date'].dt.year
games_fecha_filtrado.head()
# Out:
#        game_date   game_id  team_id_home  team_id_away  pts_home  pts_away  \
# 52071 2013-04-20  41200161    1610612743    1610612744      97.0      95.0
# 52072 2013-04-20  41200131    1610612751    1610612741     106.0      89.0
# 52073 2013-04-20  41200111    1610612752    1610612738      85.0      78.0
# 52074 2013-04-20  41200171    1610612746    1610612763     112.0      91.0
# 52075 2013-04-21  41200121    1610612754    1610612737     107.0      90.0
#
#        year
# 52071  2013
# 52072  2013
# 52073  2013
# 52074  2013
# 52075  2013

# %%
#Cargare el conjuto de datos de team
teams = pd.read_csv(r'C:\Users\USER\Desktop\Proyecto\Files\team.csv')
teams.head()
# Out:
#            id             full_name abbreviation   nickname         city  \
# 0  1610612737         Atlanta Hawks          ATL      Hawks      Atlanta
# 1  1610612738        Boston Celtics          BOS    Celtics       Boston
# 2  1610612739   Cleveland Cavaliers          CLE  Cavaliers    Cleveland
# 3  1610612740  New Orleans Pelicans          NOP   Pelicans  New Orleans
# 4  1610612741         Chicago Bulls          CHI      Bulls      Chicago
#
#            state  year_founded
# 0        Atlanta        1949.0
# 1  Massachusetts        1946.0
# 2           Ohio        1970.0
# 3      Louisiana        2002.0
# 4       Illinois        1966.0

# %%
teams = team[['id', 'city', 'nickname']]
teams.head()
# Out:
#            id         city   nickname
# 0  1610612737      Atlanta      Hawks
# 1  1610612738       Boston    Celtics
# 2  1610612739    Cleveland  Cavaliers
# 3  1610612740  New Orleans   Pelicans
# 4  1610612741      Chicago      Bulls

# %%
home_games = pd.merge(games_fecha_filtrado, teams, left_on='team_id_home', right_on='id', how='inner')
home_games.head()
# Out:
#    game_date   game_id  team_id_home  team_id_away  pts_home  pts_away  year  \
# 0 2013-04-20  41200161    1610612743    1610612744      97.0      95.0  2013
# 1 2013-04-20  41200131    1610612751    1610612741     106.0      89.0  2013
# 2 2013-04-20  41200111    1610612752    1610612738      85.0      78.0  2013
# 3 2013-04-20  41200171    1610612746    1610612763     112.0      91.0  2013
# 4 2013-04-21  41200121    1610612754    1610612737     107.0      90.0  2013
#
#            id         city  nickname
# 0  1610612743       Denver   Nuggets
# 1  1610612751     Brooklyn      Nets
# 2  1610612752     New York    Knicks
# 3  1610612746  Los Angeles  Clippers
# 4  1610612754      Indiana    Pacers

# %%
home_games = home_games.rename(columns={
    'city': 'city_home',
    'nickname': 'nickname_home'
})
home_games.head()
# Out:
#    game_date   game_id  team_id_home  team_id_away  pts_home  pts_away  year  \
# 0 2013-04-20  41200161    1610612743    1610612744      97.0      95.0  2013
# 1 2013-04-20  41200131    1610612751    1610612741     106.0      89.0  2013
# 2 2013-04-20  41200111    1610612752    1610612738      85.0      78.0  2013
# 3 2013-04-20  41200171    1610612746    1610612763     112.0      91.0  2013
# 4 2013-04-21  41200121    1610612754    1610612737     107.0      90.0  2013
#
#            id    city_home nickname_home
# 0  1610612743       Denver       Nuggets
# 1  1610612751     Brooklyn          Nets
# 2  1610612752     New York        Knicks
# 3  1610612746  Los Angeles      Clippers
# 4  1610612754      Indiana        Pacers

# %%
both_games = pd.merge(home_games, teams, left_on='team_id_away', right_on='id', how='inner')
both_games.head()
# Out:
#    game_date   game_id  team_id_home  team_id_away  pts_home  pts_away  year  \
# 0 2013-04-20  41200161    1610612743    1610612744      97.0      95.0  2013
# 1 2013-04-20  41200131    1610612751    1610612741     106.0      89.0  2013
# 2 2013-04-20  41200111    1610612752    1610612738      85.0      78.0  2013
# 3 2013-04-20  41200171    1610612746    1610612763     112.0      91.0  2013
# 4 2013-04-21  41200121    1610612754    1610612737     107.0      90.0  2013
#
#          id_x    city_home nickname_home        id_y          city   nickname
# 0  1610612743       Denver       Nuggets  1610612744  Golden State   Warriors
# 1  1610612751     Brooklyn          Nets  1610612741       Chicago      Bulls
# 2  1610612752     New York        Knicks  1610612738        Boston    Celtics
# 3  1610612746  Los Angeles      Clippers  1610612763       Memphis  Grizzlies
# 4  1610612754      Indiana        Pacers  1610612737       Atlanta      Hawks

# %%
both_games = both_home_games.rename(columns={
    'city': 'city_away',
    'nickname': 'nickname_away'
})
both_games.head()
# Out:
#    game_date   game_id  team_id_home  team_id_away  pts_home  pts_away  year  \
# 0 2013-04-20  41200161    1610612743    1610612744      97.0      95.0  2013
# 1 2013-04-20  41200131    1610612751    1610612741     106.0      89.0  2013
# 2 2013-04-20  41200111    1610612752    1610612738      85.0      78.0  2013
# 3 2013-04-20  41200171    1610612746    1610612763     112.0      91.0  2013
# 4 2013-04-21  41200121    1610612754    1610612737     107.0      90.0  2013
#
#          id_x    city_home nickname_home        id_y     city_away  \
# 0  1610612743       Denver       Nuggets  1610612744  Golden State
# 1  1610612751     Brooklyn          Nets  1610612741       Chicago
# 2  1610612752     New York        Knicks  1610612738        Boston
# 3  1610612746  Los Angeles      Clippers  1610612763       Memphis
# 4  1610612754      Indiana        Pacers  1610612737       Atlanta
#
#   nickname_away
# 0      Warriors
# 1         Bulls
# 2       Celtics
# 3     Grizzlies
# ...

# %%
both_games = both_games.drop(columns=[
    'team_id_home', 'team_id_away', 'id_x', 'id_y'
])
both_games.head()
# Out:
#    game_date   game_id  pts_home  pts_away  year    city_home nickname_home  \
# 0 2013-04-20  41200161      97.0      95.0  2013       Denver       Nuggets
# 1 2013-04-20  41200131     106.0      89.0  2013     Brooklyn          Nets
# 2 2013-04-20  41200111      85.0      78.0  2013     New York        Knicks
# 3 2013-04-20  41200171     112.0      91.0  2013  Los Angeles      Clippers
# 4 2013-04-21  41200121     107.0      90.0  2013      Indiana        Pacers
#
#       city_away nickname_away
# 0  Golden State      Warriors
# 1       Chicago         Bulls
# 2        Boston       Celtics
# 3       Memphis     Grizzlies
# 4       Atlanta         Hawks

# %% [markdown]
# Preparacion de datos

# %%
games = both_games.copy()
games.head()
# Out:
#    game_date   game_id  pts_home  pts_away  year    city_home nickname_home  \
# 0 2013-04-20  41200161      97.0      95.0  2013       Denver       Nuggets
# 1 2013-04-20  41200131     106.0      89.0  2013     Brooklyn          Nets
# 2 2013-04-20  41200111      85.0      78.0  2013     New York        Knicks
# 3 2013-04-20  41200171     112.0      91.0  2013  Los Angeles      Clippers
# 4 2013-04-21  41200121     107.0      90.0  2013      Indiana        Pacers
#
#       city_away nickname_away
# 0  Golden State      Warriors
# 1       Chicago         Bulls
# 2        Boston       Celtics
# 3       Memphis     Grizzlies
# 4       Atlanta         Hawks

# %%
games['total_points'] = games['pts_home'] + games['pts_away']
games.head()
# Out:
#    game_date   game_id  pts_home  pts_away  year    city_home nickname_home  \
# 0 2013-04-20  41200161      97.0      95.0  2013       Denver       Nuggets
# 1 2013-04-20  41200131     106.0      89.0  2013     Brooklyn          Nets
# 2 2013-04-20  41200111      85.0      78.0  2013     New York        Knicks
# 3 2013-04-20  41200171     112.0      91.0  2013  Los Angeles      Clippers
# 4 2013-04-21  41200121     107.0      90.0  2013      Indiana        Pacers
#
#       city_away nickname_away  total_points
# 0  Golden State      Warriors         192.0
# 1       Chicago         Bulls         195.0
# 2        Boston       Celtics         163.0
# 3       Memphis     Grizzlies         203.0
# 4       Atlanta         Hawks         197.0

# %%
games.nlargest(n=5, columns='total_points')
# Out:
#        game_date   game_id  pts_home  pts_away  year    city_home  \
# 13078 2023-02-24  22200902     175.0     176.0  2023  Los Angeles
# 8063  2019-03-01  21800928     161.0     168.0  2019      Atlanta
# 8501  2019-10-30  21900061     158.0     159.0  2019   Washington
# 11695 2022-02-25  22100899     153.0     157.0  2022   Washington
# 9419  2020-07-31  21901238     149.0     153.0  2020       Dallas
#
#       nickname_home    city_away nickname_away  total_points
# 13078      Clippers   Sacramento         Kings         351.0
# 8063          Hawks      Chicago         Bulls         329.0
# 8501        Wizards      Houston       Rockets         317.0
# 11695       Wizards  San Antonio         Spurs         310.0
# 9419      Mavericks      Houston       Rockets         302.0

# %%
games.nsmallest(n=5, columns='total_points')
# Out:
#       game_date   game_id  pts_home  pts_away  year      city_home  \
# 1656 2014-11-16  21400144      65.0      69.0  2014  Oklahoma City
# 1541 2014-11-01  21400028      69.0      71.0  2014      Charlotte
# 1456 2014-04-29  41300135      69.0      75.0  2014        Chicago
# 4522 2016-11-18  21600180      64.0      80.0  2016         Dallas
# 7019 2017-10-08  11700043      75.0      69.0  2017    Los Angeles
#
#      nickname_home   city_away nickname_away  total_points
# 1656       Thunder     Houston       Rockets         134.0
# 1541       Hornets     Memphis     Grizzlies         140.0
# 1456         Bulls  Washington       Wizards         144.0
# 4522     Mavericks     Memphis     Grizzlies         144.0
# 7019        Lakers  Sacramento         Kings         144.0

# %% [markdown]
# Graficacion
